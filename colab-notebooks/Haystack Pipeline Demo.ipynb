# %% [markdown]
# This demonstrates how to create a QA Pipeline using Haystack and HF models

# %% [markdown]
# Make sure you're using a GPU runtime

# %%
# !nvidia-smi
# Out:
# Wed Jan 26 22:52:47 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.46       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0    26W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# Install dependencies

# %%
# %%capture
# !pip install farm-haystack docker

# %% [markdown]
# Pull Docker image and run test container
# [source](https://haystack.deepset.ai/components/document-store)

# %%
# !docker pull opensearchproject/opensearch:1.0.1
# !docker run -p 9200:9200 -p 9600:9600 -e "discovery.type=single-node" opensearchproject/opensearch:1.0.1
# Out:
# /bin/bash: docker: command not found
# /bin/bash: docker: command not found
